# %%
import pandas as pd
import numpy as np
import nltk
import string
import re

# %%
def load_data():
    data = pd.read_excel('DatasetText021.xlsx')
    return data

# %%
kalimat_df = load_data()

# %%
df = pd.DataFrame(kalimat_df[['No', 'Kalimat']])

# %%
df
# Out:
#       No                                            Kalimat
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
# [200 rows x 2 columns]

# %%
kalimat_df.head(200)
# Out:
#       No                                            Kalimat
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
# [200 rows x 2 columns]

# %%
def remove(kalimat):
    #remove angka
    kalimat = re.sub('[0-9]+', '', kalimat)
    return kalimat
df['remove_angka'] = df['Kalimat'].apply(lambda x: remove(x))

# %%
df
# Out:
#       No                                            Kalimat  \
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
#                                           remove_angka
# 0         Apa kau pernah bertemu dengannya sebelumnya?
# 1            Ada banyak gula di dalam kotak hitam ini.
# 2     Max melihat ke dalam cermin selama ia berbicara.
# 3                 Aku berkenalan dengannya di Prancis.
# 4      Banyak orang berkumpul untuk melihat konsernya.
# ..                                                 ...
# 195                               Semua anggota hadir.
# 196  Aku berusaha untuk menghentikan pertengkaran itu.
# 197                         Rapatnya diadakan kemarin.
# 198                     Rapatnya sudah hampir selesai.
# 199                      Bagaimana menurutmu pestanya?
#
# [200 rows x 3 columns]

# %%
df.drop_duplicates(subset ="remove_angka", keep = 'first', inplace = True)

# %%
df
# Out:
#       No                                            Kalimat  \
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
#                                           remove_angka
# 0         Apa kau pernah bertemu dengannya sebelumnya?
# 1            Ada banyak gula di dalam kotak hitam ini.
# 2     Max melihat ke dalam cermin selama ia berbicara.
# 3                 Aku berkenalan dengannya di Prancis.
# 4      Banyak orang berkumpul untuk melihat konsernya.
# ..                                                 ...
# 195                               Semua anggota hadir.
# 196  Aku berusaha untuk menghentikan pertengkaran itu.
# 197                         Rapatnya diadakan kemarin.
# 198                     Rapatnya sudah hampir selesai.
# 199                      Bagaimana menurutmu pestanya?
#
# [200 rows x 3 columns]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\USER-
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#import stopword
from nltk.corpus import stopwords 
stopwords_indonesia = stopwords.words('indonesian')
 
#import sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#tokenize
from nltk.tokenize import TweetTokenizer
 
# Happy Emoticons
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
 
# Sad Emoticons
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])
 
# all emoticons (happy + sad)
emoticons = emoticons_happy.union(emoticons_sad)
 
def clean_kalimats(kalimat):
 
    # remove hyperlinks
    kalimat = re.sub(r'https?:\/\/.*[\r\n]*', '', kalimat)
    
    # remove hashtags
    # only removing the hash # sign from the word
    kalimat = re.sub(r'#', '', kalimat)
    
    #remove coma
    kalimat = re.sub(r',','',kalimat)
    
    #remove angka
    kalimat = re.sub('[0-9]+', '', kalimat)
 
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    kalimat_tokens = tokenizer.tokenize(kalimat)
 
    kalimats_clean = []    
    for word in kalimat_tokens:
        if (word not in stopwords_indonesia and # remove stopwords
              word not in emoticons and # remove emoticons
                word not in string.punctuation): # remove punctuation
            #tweets_clean.append(word)
            stem_word = stemmer.stem(word) # stemming word
            kalimats_clean.append(stem_word)
 
    return kalimats_clean

# %%
df['kalimat_clean'] = df['remove_angka'].apply(lambda x: clean_kalimats(x))

# %%
df
# Out:
#       No                                            Kalimat  \
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
#                                           remove_angka  \
# 0         Apa kau pernah bertemu dengannya sebelumnya?
# 1            Ada banyak gula di dalam kotak hitam ini.
# 2     Max melihat ke dalam cermin selama ia berbicara.
# 3                 Aku berkenalan dengannya di Prancis.
# 4      Banyak orang berkumpul untuk melihat konsernya.
# ..                                                 ...
# 195                               Semua anggota hadir.
# 196  Aku berusaha untuk menghentikan pertengkaran itu.
# 197                         Rapatnya diadakan kemarin.
# 198                     Rapatnya sudah hampir selesai.
# 199                      Bagaimana menurutmu pestanya?
#
#                kalimat_clean
# 0        [kau, temu, dengan]
# 1       [gula, kotak, hitam]
# 2      [max, cermin, bicara]
# 3     [nal, dengan, prancis]
# 4    [orang, kumpul, konser]
# ..                       ...
# 195         [anggota, hadir]
# 196  [usaha, henti, tengkar]
# 197    [rapat, ada, kemarin]
# 198         [rapat, selesai]
# 199           [turut, pesta]
#
# [200 rows x 4 columns]

# %%
def remove_punct(Kalimat):
    Kalimat  = " ".join([char for char in Kalimat if char not in string.punctuation])
    return Kalimat

# %%
df['kalimat_baru'] = df['kalimat_clean'].apply(lambda x: remove_punct(x))

# %%
df
# Out:
#       No                                            Kalimat  \
# 0    401       Apa kau pernah bertemu dengannya sebelumnya?
# 1    402          Ada banyak gula di dalam kotak hitam ini.
# 2    403   Max melihat ke dalam cermin selama ia berbicara.
# 3    404               Aku berkenalan dengannya di Prancis.
# 4    405    Banyak orang berkumpul untuk melihat konsernya.
# ..   ...                                                ...
# 195  596                               Semua anggota hadir.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 197  598                         Rapatnya diadakan kemarin.
# 198  599                     Rapatnya sudah hampir selesai.
# 199  600                      Bagaimana menurutmu pestanya?
#
#                                           remove_angka  \
# 0         Apa kau pernah bertemu dengannya sebelumnya?
# 1            Ada banyak gula di dalam kotak hitam ini.
# 2     Max melihat ke dalam cermin selama ia berbicara.
# 3                 Aku berkenalan dengannya di Prancis.
# 4      Banyak orang berkumpul untuk melihat konsernya.
# ..                                                 ...
# 195                               Semua anggota hadir.
# 196  Aku berusaha untuk menghentikan pertengkaran itu.
# 197                         Rapatnya diadakan kemarin.
# 198                     Rapatnya sudah hampir selesai.
# 199                      Bagaimana menurutmu pestanya?
#
#                kalimat_clean         kalimat_baru
# 0        [kau, temu, dengan]      kau temu dengan
# 1       [gula, kotak, hitam]     gula kotak hitam
# 2      [max, cermin, bicara]    max cermin bicara
# 3     [nal, dengan, prancis]   nal dengan prancis
# 4    [orang, kumpul, konser]  orang kumpul konser
# ..                       ...                  ...
# 195         [anggota, hadir]        anggota hadir
# 196  [usaha, henti, tengkar]  usaha henti tengkar
# 197    [rapat, ada, kemarin]    rapat ada kemarin
# 198         [rapat, selesai]        rapat selesai
# 199           [turut, pesta]          turut pesta
#
# [200 rows x 5 columns]

# %%
df.sort_values("kalimat_baru", inplace = True)

# %%
df
# Out:
#       No                                            Kalimat  \
# 134  535     Ini adalah hal yang penting bagi kalian semua.
# 12   413          Dia tidak pernah lagi mengatakan hal itu.
# 49   450               Paling tidak aku tidak seorang diri.
# 106  507             Dahulu segalanya tidaklah seperti ini.
# 136  537                             Tidak ada yang datang.
# ..   ...                                                ...
# 166  567                       Itu tak akan pernah berubah.
# 196  597  Aku berusaha untuk menghentikan pertengkaran itu.
# 181  582       Aku bekerja di sebuah perusahaan pengapalan.
# 93   494  Usianya akan menjadi tujuh belas tahun pada bu...
# 107  508  Zoologi adalah ilmu yang mempelajari tentang h...
#
#                                           remove_angka  \
# 134     Ini adalah hal yang penting bagi kalian semua.
# 12           Dia tidak pernah lagi mengatakan hal itu.
# 49                Paling tidak aku tidak seorang diri.
# 106             Dahulu segalanya tidaklah seperti ini.
# 136                             Tidak ada yang datang.
# ..                                                 ...
# 166                       Itu tak akan pernah berubah.
# 196  Aku berusaha untuk menghentikan pertengkaran itu.
# 181       Aku bekerja di sebuah perusahaan pengapalan.
# 93   Usianya akan menjadi tujuh belas tahun pada bu...
# 107  Zoologi adalah ilmu yang mempelajari tentang h...
#
#                       kalimat_clean               kalimat_baru
# 134                              []
# 12                               []
# 49                               []
# 106                              []
# 136                              []
# ..                              ...                        ...
# 166                          [ubah]                       ubah
# 196         [usaha, henti, tengkar]        usaha henti tengkar
# 181                  [usaha, kapal]                usaha kapal
# 93   [usia, tujuh, belas, februari]  usia tujuh belas februari
# 107    [zoologi, ilmu, ajar, hewan]    zoologi ilmu ajar hewan
#
# [200 rows x 5 columns]

# %%
df.drop(df.columns[[1,2,3]], axis = 1, inplace = True)

# %%
df
# Out:
#       No               kalimat_baru
# 134  535
# 12   413
# 49   450
# 106  507
# 136  537
# ..   ...                        ...
# 166  567                       ubah
# 196  597        usaha henti tengkar
# 181  582                usaha kapal
# 93   494  usia tujuh belas februari
# 107  508    zoologi ilmu ajar hewan
#
# [200 rows x 2 columns]

# %%
df.drop_duplicates(subset ="kalimat_baru", keep = 'first', inplace = True)

# %%
df
# Out:
#       No                 kalimat_baru
# 134  535
# 73   474             adik ting konyol
# 145  546                         ajar
# 176  577  ajar bahasa inggris sekolah
# 16   417          ajar tap dance muda
# ..   ...                          ...
# 166  567                         ubah
# 196  597          usaha henti tengkar
# 181  582                  usaha kapal
# 93   494    usia tujuh belas februari
# 107  508      zoologi ilmu ajar hewan
#
# [193 rows x 2 columns]

# %%
df.to_excel('outputPPDMfix.xlsx',encoding='utf8', index=False)
df
# Out:
#       No                 kalimat_baru
# 134  535
# 73   474             adik ting konyol
# 145  546                         ajar
# 176  577  ajar bahasa inggris sekolah
# 16   417          ajar tap dance muda
# ..   ...                          ...
# 166  567                         ubah
# 196  597          usaha henti tengkar
# 181  582                  usaha kapal
# 93   494    usia tujuh belas februari
# 107  508      zoologi ilmu ajar hewan
#
# [193 rows x 2 columns]
